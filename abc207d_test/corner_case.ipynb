# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
plt.figure(figsize=(6,6))
plt.plot([0-10,12-10,8-10,0-10],[0-10,5-10,20-10,0-10],marker="o",color="C1")
plt.plot([0-10,13-10,15.0769-10,0-10],[0-10,0-10,15.3846-10,0-10],marker="o", color="C1")
plt.plot([0-10,13-10,15-10,0-10],[0-10,0-10,15-10,0-10],marker="o",color="C0")
plt.xlim(-11,11)
plt.xticks(np.arange(-11,11,1))
plt.ylim(-11,11)
plt.yticks(np.arange(-11,11,1))
plt.grid()
